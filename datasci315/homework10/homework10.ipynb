# %% [markdown]
# # DATASCI 315, Homework 10: CNN Concepts and Theory
#
# This homework assignment covers theoretical concepts from Chapter 10 of *Understanding Deep Learning* by Simon J.D. Prince.
#
# **Textbook:** [Understanding Deep Learning](https://udlbook.github.io/udlbook/) (free PDF available)
#
# **Instructions:** For each problem, write your answer in the solution block provided. You may use LaTeX for mathematical notation (e.g., `$x^2$` renders as $x^2$). Refer to the textbook for the full problem statements.

# %% [markdown]
# This assignment covers CNN theory through problems from *Understanding Deep Learning*: convolution operations, pooling layers, and translation equivariance.

# %% [markdown]
# ---
#
# **Problem 1:** UDL 10.3
#
# Write out the equation for the 1D dilated convolution with a kernel size of three and a dilation rate of two, as pictured in UDL Figure 10.3d.
#
# ![UDL Figure 10.3](fig10_3.svg)
#
# *UDL Figure 10.3: 1D convolution variations. a–b) Strided convolution with stride 2. c) Convolution with kernel size 5. d) Dilated convolution with dilation rate 2.*

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 2:** UDL 10.4
#
# Write out the equation for a 1D convolution with kernel size of seven, a dilation rate of three, and a stride of three.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 3:** UDL 10.5
#
# Draw weight matrices in the style of UDL Figure 10.4d for (i) the strided convolution in UDL Figure 10.3a–b, (ii) the convolution with kernel size 5 in UDL Figure 10.3c, and (iii) the dilated convolution in UDL Figure 10.3d.
#
# ![UDL Figure 10.3](fig10_3.svg)
#
# *UDL Figure 10.3: 1D convolution variations. a–b) Strided convolution with stride 2. c) Convolution with kernel size 5. d) Dilated convolution with dilation rate 2.*
#
# ![UDL Figure 10.4](fig10_4.svg)
#
# *UDL Figure 10.4: Weight matrix representation of 1D convolution. d) Shows how convolution can be expressed as a sparse matrix multiplication.*

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 4:** UDL 10.8
#
# Consider a 1D convolutional network where the input has three channels. The first hidden layer is computed using a kernel size of three and has four channels. The second hidden layer is computed using a kernel size of five and has ten channels. How many biases and how many weights are needed for each of these two convolutional layers?

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 5:** UDL 10.9
#
# A network consists of three 1D convolutional layers. At each layer, a zero-padded convolution with kernel size three, stride one, and dilation one is applied. What size is the receptive field of the hidden units in the third layer?

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 6:** UDL 10.10
#
# A network consists of three 1D convolutional layers. At each layer, a zero-padded convolution with kernel size seven, stride one, and dilation one is applied. What size is the receptive field of hidden units in the third layer?

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 7:** UDL 10.11
#
# Consider a convolutional network with 1D input $\mathbf{x}$. The first hidden layer $\mathbf{H}_1$ is computed using a convolution with kernel size five, stride two, and a dilation rate of one. The second hidden layer $\mathbf{H}_2$ is computed using a convolution with kernel size three, stride one, and a dilation rate of one. The third hidden layer $\mathbf{H}_3$ is computed using a convolution with kernel size five, stride one, and a dilation rate of two. What are the receptive field sizes at each hidden layer?

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION

# %% [markdown]
# ---
#
# **Problem 8:** UDL 10.14
#
# Consider a 2D convolutional layer with kernel size $5 \times 5$ that takes 3 input channels and returns 10 output channels. How many convolutional weights are there? How many biases?

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
#
# > END SOLUTION
