# %% [markdown]
# # DATASCI 315, Homework 10: CNN Concepts and Theory
#
# This homework assignment covers theoretical concepts from Chapter 10 of *Understanding Deep Learning* by Simon J.D. Prince.
#
# **Instructions:** For each problem, write your answer in the solution block provided. You may use LaTeX for mathematical notation (e.g., `$x^2$` renders as $x^2$). Refer to the textbook for the full problem statements.

# %% [markdown]
# This assignment explores the theoretical foundations of **convolutional neural networks (CNNs)** through problems from *Understanding Deep Learning*. You'll deepen your understanding of convolution operations, pooling layers, and how CNNs achieve translation equivariance—concepts that complement the practical CNN implementations from earlier assignments.

# %% [markdown]
# ### Problem 1: UDL 10.3
#
# Refer to Problem 10.3 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 2: UDL 10.4
#
# Refer to Problem 10.4 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 3: UDL 10.5
#
# Refer to Problem 10.5 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 4: UDL 10.8
#
# Refer to Problem 10.8 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 5: UDL 10.9
#
# Refer to Problem 10.9 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 6: UDL 10.10
#
# Refer to Problem 10.10 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 7: UDL 10.11
#
# Refer to Problem 10.11 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION

# %% [markdown]
# ### Problem 8: UDL 10.14
#
# Refer to Problem 10.14 in *Understanding Deep Learning*, Chapter 10.

# %% [markdown]
# > BEGIN SOLUTION
#
# *Your answer here.*
# > END SOLUTION
