# %% [markdown]
# # DATASCI 315, Homework 5: Shallow Networks, Loss Functions, and Fitting (Concepts and Theory)

# %% [markdown]
# This homework assignment consists of problems from our textbook, *Understanding Deep Learning* (UDL). To submit your solutions, which may be handwritten or typed, please upload a PDF file containing them to Canvas. If your solutions are handwritten on paper, one way to convert them to a PDF is by using the Google Drive app's scan functionality.

# %% [markdown]
# ## UDL Chapter 3: Shallow Neural Networks

# %% [markdown]
# ### Problem 1: UDL 3.4

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ### Problem 2: UDL 3.8

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ### Problem 3: UDL 3.14

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ### Problem 4: UDL 3.16

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ## UDL Chapter 5: Loss Functions

# %% [markdown]
# ### Problem 5: UDL 5.5

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ### Problem 6: UDL 5.6

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ### Problem 7: UDL 5.7

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION

# %% [markdown]
# ## UDL Chapter 6: Fitting Models

# %% [markdown]
# ### Problem 8: UDL 6.9

# %% [markdown]
# # BEGIN SOLUTION
# *Write your solution here.*
# # END SOLUTION
